# %%
import os
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
import pandas as pd
import glob
import numpy as np
import seaborn as sb
df = pd.read_excel('/workspaces/repos/Trabajo/obesidad.xls')

# %%
#EXPLORACION DE DATOS
#Mostrar DataFrame en pantalla
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
#Mostrar informacion detallada
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/repos/Trabajo/a.ipynb Celda 3 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bsolid-space-guide-g9w96qvxw45hv7q9/workspaces/repos/Trabajo/a.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #Mostrar informacion detallada
# ----> <a href='vscode-notebook-cell://codespaces%2Bsolid-space-guide-g9w96qvxw45hv7q9/workspaces/repos/Trabajo/a.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df.info()
#
# NameError: name 'df' is not defined

# %%
#Mostrar cantidad de filas y columnas
filas, columnas = df.shape
print("N° de filas: ", filas)
print("N° de columnas: ", columnas)
# Out:
# N° de filas:  2111
# N° de columnas:  17

# %%
#Mostrar el tipo de datos del Data Frame
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
#Muestra los 30 primeras  filas
df.head(30)
# Out:
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0   Female  21.0    1.62    64.0                            yes   no   2.0
# 1   Female  21.0    1.52    56.0                            yes   no   3.0
# 2     Male  23.0    1.80    77.0                            yes   no   2.0
# 3     Male  27.0    1.80    87.0                             no   no   3.0
# 4     Male  22.0    1.78    89.8                             no   no   2.0
# 5     Male  29.0    1.62    53.0                             no  yes   2.0
# 6   Female  23.0    1.50    55.0                            yes  yes   3.0
# 7     Male  22.0    1.64    53.0                             no   no   2.0
# 8     Male  24.0    1.78    64.0                            yes  yes   3.0
# 9     Male  22.0    1.72    68.0                            yes  yes   2.0
# 10    Male  26.0    1.85   105.0                            yes  yes   3.0
# ...

# %%
#Muestra mapa de calor de valores nulos(NA)
plt.figure(figsize = (8,6))
sb.heatmap(df.isnull(), cbar=False , cmap = 'magma')
# Out:
# <Axes: >

# %%
#Mostrar la cantidad de datos nulos dentro de cada columna del dataset
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
#Busqueda de las filas duplicadas del dataset
df_duplicados = df[df.duplicated()]
df_duplicados
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 309  Female  16.0    1.66    58.0                             no   no   2.0
# 460  Female  18.0    1.62    55.0                            yes  yes   2.0
# 467    Male  22.0    1.74    75.0                            yes  yes   3.0
# 496    Male  18.0    1.72    53.0                            yes  yes   2.0
# 527  Female  21.0    1.52    42.0                             no  yes   3.0
# ...

# %%
#Realizar conteo de filas duplicadas
conteo_repeticiones = df.duplicated().sum()
print(f"El número de filas duplicadas en el DataFrame es: {conteo_repeticiones}")
# Out:
# El número de filas duplicadas en el DataFrame es: 24

# %%
#TRANSFORMACIÓN DE DATOS
#Cambiamos algunos nombres de los indices de ingles a español
df.columns = ['Genero', 'Edad', 'Altura', 'Peso', 'Historia_familiar_con_sobrepeso', 'FAVC', 'FCVC', 'NCP', 'CAEC', 'Fuman', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'Medio_de_transporte', 'NObeyesdad']
df
# Out:
#       Genero       Edad    Altura        Peso Historia_familiar_con_sobrepeso  \
# 0     Female  21.000000  1.620000   64.000000                             yes
# 1     Female  21.000000  1.520000   56.000000                             yes
# 2       Male  23.000000  1.800000   77.000000                             yes
# 3       Male  27.000000  1.800000   87.000000                              no
# 4       Male  22.000000  1.780000   89.800000                              no
# ...      ...        ...       ...         ...                             ...
# 2106  Female  20.976842  1.710730  131.408528                             yes
# 2107  Female  21.982942  1.748584  133.742943                             yes
# 2108  Female  22.524036  1.752206  133.689352                             yes
# 2109  Female  24.361936  1.739450  133.346641                             yes
# 2110  Female  23.664709  1.738836  133.472641                             yes
#
# ...

# %%
#Cambiamos palabras de ingles a español en el data set
df.loc[df['Genero'] == 'Female', 'Genero'] = 'Femenino'
df.loc[df['Genero'] == 'Male', 'Genero'] = 'Masculino'
df.loc[df['Historia_familiar_con_sobrepeso'] == 'yes', 'Historia_familiar_con_sobrepeso'] = 'si'
df.loc[df['FAVC'] == 'yes', 'FAVC'] = 'si'
df.loc[df['CAEC'] == 'Sometimes', 'CAEC'] = 'A veces'
df.loc[df['CALC'] == 'Always', 'CALC'] = 'Siempre'
df.loc[df['CAEC'] == 'Frequently', 'CAEC'] = 'Frecuentemente'
df.loc[df['Fuman'] == 'yes', 'Fuman'] = 'si'
df.loc[df['SCC'] == 'yes', 'SCC'] = 'si'
df.loc[df['CALC'] == 'Sometimes', 'CALC'] = 'A veces'
df.loc[df['CALC'] == 'Frequently', 'CALC'] = 'Frecuentemente'
df.loc[df['Medio_de_transporte'] == 'Public_Transportation', 'Medio_de_transporte'] = 'Trasporte_publico'
df.loc[df['Medio_de_transporte'] == 'Walking', 'Medio_de_transporte'] = 'Caminando'
df.loc[df['Medio_de_transporte'] == 'Automobile', 'Medio_de_transporte'] = 'Automovil'
df.loc[df['Medio_de_transporte'] == 'Bike', 'Medio_de_transporte'] = 'Bicicleta'
df.loc[df['NObeyesdad'] == 'Normal_Weight', 'NObeyesdad'] = 'Peso_normal'
df.loc[df['NObeyesdad'] == 'Insufficient_Weight', 'NObeyesdad'] = 'Peso_insufuciente'
df.loc[df['NObeyesdad'] == 'Obesity_Type_I', 'NObeyesdad'] = 'Obesidad_tipo_I'
df.loc[df['NObeyesdad'] == 'Obesity_Type_II', 'NObeyesdad'] = 'Obesidad_tipo_II'
df.loc[df['NObeyesdad'] == 'Obesity_Type_III', 'NObeyesdad'] = 'Obesidad_tipo_III'
df.loc[df['NObeyesdad'] == 'Overweight_Level_I', 'NObeyesdad'] = 'Nivel_de_sobrepeso_I'
df.loc[df['NObeyesdad'] == 'Overweight_Level_II', 'NObeyesdad'] = 'Nivel_de_sobrepeso_II'
df.loc[df['NObeyesdad'] == 'Overweight_Level_III', 'NObeyesdad'] = 'Nivel_de_sobrepeso_III'

df
# Out:
#          Genero       Edad    Altura        Peso  \
# 0      Femenino  21.000000  1.620000   64.000000
# 1      Femenino  21.000000  1.520000   56.000000
# 2     Masculino  23.000000  1.800000   77.000000
# 3     Masculino  27.000000  1.800000   87.000000
# 4     Masculino  22.000000  1.780000   89.800000
# ...         ...        ...       ...         ...
# 2106   Femenino  20.976842  1.710730  131.408528
# 2107   Femenino  21.982942  1.748584  133.742943
# 2108   Femenino  22.524036  1.752206  133.689352
# 2109   Femenino  24.361936  1.739450  133.346641
# 2110   Femenino  23.664709  1.738836  133.472641
#
#      Historia_familiar_con_sobrepeso FAVC  FCVC  NCP     CAEC Fuman      CH2O  \
# 0                                 si   no   2.0  3.0  A veces    no  2.000000
# 1                                 si   no   3.0  3.0  A veces    si  3.000000
# 2                                 si   no   2.0  3.0  A veces    no  2.000000
# ...

# %%
#Cambiar tipo de dato de una columna
df['Edad'] = df['Edad'].apply(int)
df['Altura'] = df['Altura'].astype(float).round(2)
df['Peso'] = df['Peso'].astype(float).round(2)
df['CH2O'] = df['CH2O'].apply(int)
df['FAF'] = df['FAF'].apply(int)
df['TUE'] = df['TUE'].apply(int)

df
# Out:
#          Genero  Edad  Altura    Peso Historia_familiar_con_sobrepeso FAVC  \
# 0      Femenino    21    1.62   64.00                              si   no
# 1      Femenino    21    1.52   56.00                              si   no
# 2     Masculino    23    1.80   77.00                              si   no
# 3     Masculino    27    1.80   87.00                              no   no
# 4     Masculino    22    1.78   89.80                              no   no
# ...         ...   ...     ...     ...                             ...  ...
# 2106   Femenino    20    1.71  131.41                              si   si
# 2107   Femenino    21    1.75  133.74                              si   si
# 2108   Femenino    22    1.75  133.69                              si   si
# 2109   Femenino    24    1.74  133.35                              si   si
# 2110   Femenino    23    1.74  133.47                              si   si
#
# ...

# %%
# COMANDO PARA MOSTRAR EL DIAGRAMA DE BIGOTES
plt.boxplot(df['Peso'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff248d6f7c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff248d6fd00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff248d6f520>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff248d88280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff248d88520>],
#  'means': []}

# %%
#COMANDO PARA MOSTRAR DIAGRAMA DE BARRAS DE PROMEDIO DE PESOS DE HOMBRES Y MUJERES
promedios = df.groupby('Genero')['Peso'].mean()

# Crea el gráfico de barras
promedios.plot(kind='bar', color=['blue', 'pink'])
plt.title('Promedio de Pesos por Género')
plt.xlabel('Género')
plt.ylabel('Promedio de Peso')
plt.xticks(rotation=0)
plt.show()

# %%
plt.scatter(df['Edad'], df['Peso'], alpha=0.5)
plt.title('Relación entre Edad y Peso')
plt.xlabel('Edad')
plt.ylabel('Peso')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'Historia_familiar_con_sobrepeso', data = df, palette="GnBu_d",edgecolor="black")
plt.subplot(132)
sns.countplot(x= 'Medio_de_transporte', data = df, palette="flag",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'CALC', data = df, palette="Greens_r",edgecolor="black")
plt.xticks(rotation=45)
plt.show()
